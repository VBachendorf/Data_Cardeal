# %% [markdown]
# ## Lista de Atividades
#
# 🧠 Questão 1 – Verificação de idade para votação
# Você está criando um sistema para um cartório eleitoral que verifica se uma pessoa é obrigada a votar com base na idade.
#
# Requisito:
#
# ```
# Menores de 16 anos não votam.
#
# Entre 16 e 17 anos ou acima de 70 anos, o voto é facultativo.
#
# Entre 18 e 70 anos, o voto é obrigatório.
# ```
# Implemente uma estrutura condicional que analise a idade inserida e imprima a situação do voto.
# <hr>
# <br>
#
# 🛒 Questão 2 – Desconto em supermercado
# Um supermercado oferece descontos de acordo com o valor da compra:
#
# ```
# Acima de R$ 500,00: 15% de desconto.
#
# Entre R$ 300,00 e R$ 500,00: 10% de desconto.
#
# Entre R$ 100,00 e R$ 300,00: 5% de desconto.
#
# Abaixo de R$ 100,00: sem desconto.
#
# ```
# Escreva um programa que leia o valor total da compra e informe qual o percentual de desconto aplicado.
# <hr>
# <br>
#
# 🎓 Questão 3 – Classificação de notas
# Uma universidade classifica os alunos de acordo com a média final:
#
# ```
# Abaixo de 4,0: Reprovado.
#
# Entre 4,0 e 6,0: Em recuperação.
#
# Acima de 6,0: Aprovado.
# ```
#
# Crie uma estrutura condicional que classifique o aluno com base na média final.
# <hr>
# <br>
# 🚗 Questão 4 – Multa de trânsito por velocidade
# Em uma rodovia, o limite de velocidade é de 100 km/h.
# A polícia aplica multas assim:
#
# ```
# Até 100 km/h: Sem multa.
#
# De 101 a 120 km/h: Multa leve.
#
# De 121 a 150 km/h: Multa média.
#
# Acima de 150 km/h: Multa grave.
# ```
#
# Implemente uma estrutura condicional que leia a velocidade de um veículo e classifique a infração.
# <hr>
# <br>
# 💼 Questão 5 – Classificação de cargos e salários
# Uma empresa deseja classificar os cargos com base nos salários:
#
# ```
# Até R$ 2.000,00: Estagiário
#
# De R$ 2.001,00 a R$ 5.000,00: Analista
#
# De R$ 5.001,00 a R$ 10.000,00: Especialista
#
# Acima de R$ 10.000,00: Gerente
# ```
#
# Crie uma estrutura que, dado o salário de um funcionário, informe o seu cargo.
# <hr>
# <br>
# 🧾 Questão 6 – Cálculo de imposto de renda simplificado
# Considere uma tabela simples de imposto de renda:
#
# ```
# Até R$ 2.112,00: isento
#
# De R$ 2.112,01 até R$ 3.000,00: 7,5%
#
# De R$ 3.000,01 até R$ 4.000,00: 15%
#
# Acima de R$ 4.000,00: 22,5%
# ```
#
# Crie um programa que leia o salário de uma pessoa e informe qual percentual de imposto deve ser aplicado.
# <hr>
# <br>
# 💵 Questão 7 – Cálculo de imposto de renda com base em soma de rendimentos
# Um trabalhador tem rendimentos mensais provenientes de salário, aluguéis e freelancer.
# O imposto é calculado sobre a soma total dos rendimentos mensais conforme a seguinte tabela simplificada:
#
# ```
# Até R$ 2.500,00: isento
#
# De R$ 2.500,01 até R$ 4.000,00: 10%
#
# De R$ 4.000,01 até R$ 6.000,00: 15%
#
# Acima de R$ 6.000,00: 20%
# ```
#
# Crie um programa que leia os três valores e informe o percentual de imposto aplicado com base na soma.
# <hr>
# <br>
# 🏠 Questão 8 – Faixa de financiamento habitacional
# Um banco avalia se uma pessoa pode financiar um imóvel com base na soma da renda familiar (renda do titular + cônjuge). As faixas de financiamento são:
#
# ```
# Até R$ 3.000,00: não aprovado
#
# De R$ 3.001 até R$ 6.000,00: pode financiar até R$ 100.000,00
#
# De R$ 6.001 até R$ 10.000,00: pode financiar até R$ 200.000,00
#
# Acima de R$ 10.000,00: pode financiar até R$ 300.000,00
# ```
#
# Faça um programa que leia a renda do titular e do cônjuge, calcule a renda familiar e informe a faixa de financiamento.
# <hr>
# <br>
# 🏫 Questão 9 – Bolsa de estudos com base em renda per capita
# Uma escola oferece bolsas de estudos com base na renda per capita da família. A renda per capita é calculada pela soma da renda total dividida pelo número de pessoas na família.
#
# Critérios:
# ```
# Até R$ 500,00: bolsa integral
#
# De R$ 501 até R$ 1.000,00: bolsa de 50%
#
# Acima de R$ 1.000,00: sem bolsa
# ```
#
# Escreva um programa que leia a renda total da família e o número de membros, calcule a renda per capita e determine o tipo de bolsa.
# <hr>
# <br>
# 🍽️ Questão 10 – Avaliação de benefício de auxílio alimentação
# Uma empresa oferece auxílio alimentação com base no gasto mensal médio com alimentação (restaurante, mercado e lanches). A soma desses gastos define o valor do auxílio:
#
# ```
# Até R$ 300,00: auxílio de R$ 150,00
#
# De R$ 301 até R$ 600,00: auxílio de R$ 250,00
#
# Acima de R$ 600,00: auxílio de R$ 350,00
# ```
#
# Crie um programa que receba os valores dos três tipos de gastos e indique o valor do auxílio a ser recebido.
